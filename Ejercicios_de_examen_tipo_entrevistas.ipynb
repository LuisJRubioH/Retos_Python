# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisJRubioH/Retos_Python/blob/main/Ejercicios_de_examen_tipo_entrevistas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicio #1  ------------------------------------------------------------------------------**

# %% [markdown]
# **What will be the output of the following code?**

# %%
import pandas as pd

# %%
q1 = pd.Series([25,4,31,28],["Ene","feb","Mar","Abi"])
q1=q1+5
print(q1)
# Out:
# Ene    30
# feb     9
# Mar    36
# Abi    33
# dtype: int64

# %% [markdown]
# **Ejercicio #2**------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
lista=[1,7,8,12,5,9]
suma =0
for i in lista:
    if i %2 ==0:
      suma=suma+i
print(suma)
# Out:
# 20

# %% [markdown]
# **Ejercicio #3**------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
x=10
i=2
while (i<=3):
  j=2
  while j<=4 and i<=2:
      x=x+j
      j=j+1
  i=i+1

print(x)
# Out:
# 19

# %% [markdown]
# **Ejercicio #4-**-----------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
lista[1:5]
# Out:
# [7, 8, 12, 5]

# %% [markdown]
# **Ejercicio #5**  ------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
x = 1

def test():
  global x
  for x in range(3):
    pass
test()

print(x)
# Out:
# 2

# %% [markdown]
# **Ejercicio #6**------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
arr =[1,2,3]
for i in arr:
  arr.remove(i)
print(arr)
# Out:
# [2]

# %% [markdown]
# Ejercicio #17------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
x = [1,2,3]
y = x
y.append(4)
print(x)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Ejercicio #8 ------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
#
# ```python
# d ={1:10, 2:20, 3:30}
#
# for k,v in d.items():
#   print(k + v, end = " ")
#
# #A. 11 22 33
# #B. 10 20 30
# #C. 1 2 3
# #D. Error

# %% [markdown]
# **Solución**

# %%
d ={1:10, 2:20, 3:30}

for k,v in d.items():
  print(k + v, end = " ")
# Out:
# 11 22 33

# %% [markdown]
# Ejercicio #9------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
#
#
# ```python
# for i in range(3):
#   continue
#   print(i)
#
#   # A. 0 1 2
#   # B. None
#   # C. 3
#   # D. Error

# %% [markdown]
# **Solución**

# %%
for i in range(3):
  continue
  print(i)

# %% [markdown]
# Ejercicio #10------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
#
# ```python
# X = (i**2 for i in range(3))
# print(next(X))
# print(next(X))
#
# # A. 0 4
# # B. 1 4
# # C. 0 1
# # D. Error

# %% [markdown]
# **Solución**

# %%
X = (i**2 for i in range(3))
print(next(X))
print(next(X))
# Out:
# 0
# 1

# %% [markdown]
# Ejercicio #11------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
#
# ```python
# count = 0
#
# for i in range(1, 5):
#    count += i
#
# print(count)
#
# # A. 5
# # B. 10
# # C. 15
# # D. 20

# %% [markdown]
# S**olución**

# %%
count = 0
for i in range(1, 5):
   count += i

print(count)
# Out:
# 10

# %% [markdown]
# Ejercicio #12------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**

# %%
x=[[0] * 3] * 3
x[0][0] = 1
print(x)
# Out:
# [[1, 0, 0], [1, 0, 0], [1, 0, 0]]

# %% [markdown]
# Ejercicio #13------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
# **What will be the output of the following code?**
#
# ```python
# a = [1,3,5,6]
#
# x = 0
#
# for i in a:
#   if i > 4:
#     continue
#   x += i
#
# print(x)
#
# # A. 4
# # B. 15
# # C. 9
# # D. 1

# %% [markdown]
# **Solución**

# %%
a = [1,3,5,6]

x = 0

for i in a:
  if i > 4:
    continue
  x += i

print(x)
# Out:
# 4

# %% [markdown]
# Ejercicio #14  ------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
#
# ```python
# value = 2
#
# for i in range(1, 4):
#     value += (i + value)
#
# print(value)
#
# # A. 12
# # B. 20
# # C. 27
# # D. 32

# %% [markdown]
# **Solución**

# %%
value = 2

for i in range(1,4):
  value += (i + value)

print(value)
# Out:
# 27

# %% [markdown]
# Ejercicio #15  ------------------------------------------------------------------------------

# %% [markdown]
# **What will be the output of the following code?**
#
# ```python
# data = [[1,2], [3,4]]
#
# for x,y in data:
#     print(x + y, end = " ")
#
# # A. 3 7
# # B. 12
# # C. [3,7]
# # D. Error

# %% [markdown]
# *Solución*

# %%
data = [[1,2], [3,4]]

for x,y in data:
    print(x + y, end = " ")
# Out:
# 3 7

# %% [markdown]
# Ejercicio #16------------------------------------------------------------------------------

# %% [markdown]
# *What will be the output of the following code?**
#
# ```python
# d = {"a":2,"b":4, "c":6}
#
# x = 1
#
# for v in d.values():
#     x *= v
# print(v)
#
# # A. 12
# # B. 24
# # C. 48
# # D. 60

# %% [markdown]
# **Solución**

# %%
d = {"a":2,"b":4, "c":6}
x = 1
for v in d.values():
    x *= v
print(x)
# Out:
# 48

# %% [markdown]
# Ejercicio #17------------------------------------------------------------------------------

# %% [markdown]
# *What will be the output of the following code?**
#
# ```python
# def add(a, b=[]):
#   b.append(a)
#   return b
#
# print(add(1))
# print(add(12))
#
# # A. [1,2] [1,2]
# # B. [1] [1,2]
# # C. Error

# %% [markdown]
# **Solución**

# %%
def add(a, b=[]):
  b.append(a)
  return b

print(add(1))
print(add(2))
# Out:
# [1]
# [1, 2]

# %% [markdown]
# Ejercicio #18  ------------------------------------------------------------------------------
